# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import linregress
import cpi
cpi.update()

# %%
# CSV Path
imdb_movies_csv = "Data/imdb_movies.csv"
box_office_csv = "Data/boxoffice.csv"

# %%
# Variables for the seperate data frames 
imdb_df = pd.read_csv(imdb_movies_csv)
box_office_df = pd.read_csv(box_office_csv)

# %%
# Removing columns I do not need
col_imdb_df = imdb_df[['imdb_title_id', 'original_title', 'year', 'date_published', 'genre', 'duration', 'country', 
                         'language', 'director', 'writer', 'production_company', 'actors', 'avg_vote', 'votes']]

col_box_office_df = box_office_df[['title', 'lifetime_gross', 'year']]

# %%
# Renaming columns to be more uniform
col_imdb_df = col_imdb_df.rename(columns={'imdb_title_id': "IMDB ID", 'original_title': 'Title', 'year': 'Year', 
                                          'date_published': 'Date Published', 'genre': 'Genre', 'duration': 'Duration',
                                         'country': 'Country', 'language': 'Language', 'director': 'Director', 'writer': 'Writer',
                                         'production_company': 'Production Company', 'actors': 'Actors', 'avg_vote': 'Avg Rating',
                                          'votes': '# of Ratings'})

col_box_office_df = col_box_office_df.rename(columns={'title': 'Title', 'lifetime_gross': 'Lifetime_Gross', 'year': 'Year'})

# %%
# Merging data frames
movie_data = pd.merge(col_imdb_df, col_box_office_df, on=['Title', 'Year'], how='inner')

# Splicing the Genre column into multiple rows


# Dropping data that is not available through CPI
movie_data.drop(movie_data[movie_data['Year'] == 1912 ].index , inplace=True)
movie_data.drop(movie_data[movie_data['Year'] == 2019 ].index , inplace=True)
movie_data.drop(movie_data[movie_data['Year'] == 2020 ].index , inplace=True)

# %%
# Sort IMDB ID
movie_data.sort_values("IMDB ID", inplace = True)

# Drop duplicate IMDB ID
movie_data.drop_duplicates(subset ="IMDB ID", keep = False, inplace = True)

# %%
# Calculating inflation through CPI library 
# Source: https://medium.com/analytics-vidhya/adjusting-for-inflation-when-analysing-historical-data-with-python-9d69a8dcbc27
def inflate_column(data, column):
    
    return data.apply(lambda x: cpi.inflate(x[column], x.Year), axis=1)          
    
movie_data['Lifetime Gross - Adjusted ($)'] = inflate_column(movie_data, 'Lifetime_Gross')

# %%
# Converting scientific notation
movie_data["Lifetime Gross - Adjusted ($)"].describe().apply(lambda x: format(x, 'f'))
pd.options.display.float_format = '{:,.2f}'.format

# Formatting columns
movie_data['Lifetime_Gross'] = movie_data['Lifetime_Gross'].astype(float).map("${:,.2f}".format)
movie_data['Lifetime Gross - Adjusted ($)'] = movie_data['Lifetime Gross - Adjusted ($)'].astype(float).map("${:,.2f}".format)

movie_data
# Out:
#         IMDB ID                                Title  Year Date Published  \
# 0     tt0012190  The Four Horsemen of the Apocalypse  1921     1923-01-08
# 1     tt0017136                           Metropolis  1927     1927-02-06
# 2     tt0017354                        The Sea Beast  1926     1926-01-15
# 3     tt0021749                          City Lights  1931     1931-08-21
# 4     tt0027977                         Modern Times  1936     1936-10-16
# ...         ...                                  ...   ...            ...
# 7729  tt8235296                   The Trump Prophecy  2018     2018-10-02
# 7730  tt8264546                                 1991  2018     2018-07-27
# 7735  tt8427036                      Helicopter Eela  2018     2018-10-12
# 7739  tt8581198                        Jane and Emma  2018     2018-10-12
# 7745  tt8925540                             Racetime  2018     2018-12-14
#
#                              Genre  Duration  Country  \
# 0              Drama, Romance, War       150      USA
# 1                    Drama, Sci-Fi       153  Germany
# 2       Action, Adventure, Fantasy       136      USA
# 3           Comedy, Drama, Romance        87      USA
# 4            Comedy, Drama, Family        87      USA
# ...                            ...       ...      ...
# 7729                         Drama       120      USA
# 7730                        Comedy       141   Canada
# 7735                         Drama       135    India
# 7739                         Drama        90      USA
# 7745  Animation, Adventure, Comedy        89   Canada
#
#                                               Language  \
# 0                                                 None
# 1                                               German
# 2                                              English
# 3                                              English
# 4                                              English
# ...                                                ...
# 7729                                           English
# 7730  French, Italian, English, German, Greek, Spanish
# 7735                                             Hindi
# 7739                                           English
# 7745                                           English
#
#                                    Director  \
# 0                                Rex Ingram
# 1                                Fritz Lang
# 2                              Millard Webb
# 3                           Charles Chaplin
# 4                           Charles Chaplin
# ...                                     ...
# 7729                       Stephan Schultze
# 7730                          Ricardo Trogi
# 7735                         Pradeep Sarkar
# 7739                      Chantelle Squires
# 7745  Benoît Godbout, Jean-François Pouliot
#
#                                   Writer           Production Company  \
# 0     Vicente Blasco Ibáñez, June Mathis   Metro Pictures Corporation
# 1       Thea von Harbou, Thea von Harbou         Universum Film (UFA)
# 2         Herman Melville, Bess Meredyth                 Warner Bros.
# 3                        Charles Chaplin  Charles Chaplin Productions
# 4                        Charles Chaplin  Charles Chaplin Productions
# ...                                  ...                          ...
# 7729         Mary Colbert, Rick Eldridge            ReelWorks Studios
# 7730                       Ricardo Trogi                          NaN
# 7735           Mitesh Shah, Anand Gandhi            Ajay Devgn Ffilms
# 7739              Melissa Leilani Larson                          NaN
# 7745        Claude Landry, Maxime Landry          CarpeDiem Film & TV
#
#                                                  Actors  Avg Rating  \
# 0     Pomeroy Cannon, Josef Swickard, Bridgetta Clar...        7.20
# 1     Alfred Abel, Gustav Fröhlich, Rudolf Klein-Rog...        8.30
# 2     John Barrymore, Dolores Costello, George O'Har...        6.50
# 3     Virginia Cherrill, Florence Lee, Harry Myers, ...        8.50
# 4     Charles Chaplin, Paulette Goddard, Henry Bergm...        8.50
# ...                                                 ...         ...
# 7729  Chris Nelson, Paulette Todd, Karen Boles, Don ...        3.00
# 7730  Sandrine Bisson, Jean-Carl Boucher, Mamoudou C...        7.10
# 7735  Kajol, Riddhi Sen, Tota Roy Chowdhury, Neha Dh...        5.50
# 7739  Danielle Deadwyler, Emily Goss, Brad Schmidt, ...        5.90
# 7745  Sonja Ball, Hélène Bourgeois Leclerc, Mehdi Bo...        5.40
#
#       # of Ratings Lifetime_Gross Lifetime Gross - Adjusted ($)
# 0             2935  $9,183,673.00               $131,165,937.89
# 1           148396  $1,236,166.00                $18,162,901.79
# 2              126    $814,000.00                $11,757,333.22
# 3           152716     $19,181.00                   $322,615.59
# 4           197969    $163,577.00                 $3,008,604.68
# ...            ...            ...                           ...
# 7729          1669    $671,198.00                   $683,359.95
# 7730           501  $2,342,264.00                 $2,384,705.27
# 7735           800     $71,971.00                    $73,275.10
# 7739           115    $380,030.00                   $386,916.05
# 7745           227  $1,875,283.00                 $1,909,262.69
#
# [7665 rows x 16 columns]

# %%
# Creating a stacked df, exploding the Genre column into separate rows
# Source: https://www.semicolonworld.com/question/43032/split-explode-pandas-dataframe-string-entry-to-separate-rows
stacked_movie_data = (movie_data.set_index(movie_data.columns.drop('Genre',1).tolist())
                    .Genre.str.split(',', expand=True)
                    .stack()
                    .reset_index()
                    .rename(columns={0:'Genre'})
                     .loc[:, movie_data.columns])

# Creating a stacked df, exploding the Genre column into separate rows
# Source: https://www.semicolonworld.com/question/43032/split-explode-pandas-dataframe-string-entry-to-separate-rows
stacked_movie_data_actors = (stacked_movie_data.set_index(stacked_movie_data.columns.drop('Actors',1).tolist())
                    .Actors.str.split(',', expand=True)
                    .stack()
                    .reset_index()
                    .rename(columns={0:'Actors'})
                     .loc[:, stacked_movie_data.columns])

# %%
stacked_movie_data_actors
# Out:
#           IMDB ID                                Title  Year Date Published  \
# 0       tt0012190  The Four Horsemen of the Apocalypse  1921     1923-01-08
# 1       tt0012190  The Four Horsemen of the Apocalypse  1921     1923-01-08
# 2       tt0012190  The Four Horsemen of the Apocalypse  1921     1923-01-08
# 3       tt0012190  The Four Horsemen of the Apocalypse  1921     1923-01-08
# 4       tt0012190  The Four Horsemen of the Apocalypse  1921     1923-01-08
# ...           ...                                  ...   ...            ...
# 277451  tt8925540                             Racetime  2018     2018-12-14
# 277452  tt8925540                             Racetime  2018     2018-12-14
# 277453  tt8925540                             Racetime  2018     2018-12-14
# 277454  tt8925540                             Racetime  2018     2018-12-14
# 277455  tt8925540                             Racetime  2018     2018-12-14
#
#           Genre  Duration Country Language  \
# 0         Drama       150     USA     None
# 1         Drama       150     USA     None
# 2         Drama       150     USA     None
# 3         Drama       150     USA     None
# 4         Drama       150     USA     None
# ...         ...       ...     ...      ...
# 277451   Comedy        89  Canada  English
# 277452   Comedy        89  Canada  English
# 277453   Comedy        89  Canada  English
# 277454   Comedy        89  Canada  English
# 277455   Comedy        89  Canada  English
#
#                                      Director  \
# 0                                  Rex Ingram
# 1                                  Rex Ingram
# 2                                  Rex Ingram
# 3                                  Rex Ingram
# 4                                  Rex Ingram
# ...                                       ...
# 277451  Benoît Godbout, Jean-François Pouliot
# 277452  Benoît Godbout, Jean-François Pouliot
# 277453  Benoît Godbout, Jean-François Pouliot
# 277454  Benoît Godbout, Jean-François Pouliot
# 277455  Benoît Godbout, Jean-François Pouliot
#
#                                     Writer          Production Company  \
# 0       Vicente Blasco Ibáñez, June Mathis  Metro Pictures Corporation
# 1       Vicente Blasco Ibáñez, June Mathis  Metro Pictures Corporation
# 2       Vicente Blasco Ibáñez, June Mathis  Metro Pictures Corporation
# 3       Vicente Blasco Ibáñez, June Mathis  Metro Pictures Corporation
# 4       Vicente Blasco Ibáñez, June Mathis  Metro Pictures Corporation
# ...                                    ...                         ...
# 277451        Claude Landry, Maxime Landry         CarpeDiem Film & TV
# 277452        Claude Landry, Maxime Landry         CarpeDiem Film & TV
# 277453        Claude Landry, Maxime Landry         CarpeDiem Film & TV
# 277454        Claude Landry, Maxime Landry         CarpeDiem Film & TV
# 277455        Claude Landry, Maxime Landry         CarpeDiem Film & TV
#
#                             Actors  Avg Rating  # of Ratings Lifetime_Gross  \
# 0                   Pomeroy Cannon        7.20          2935  $9,183,673.00
# 1                   Josef Swickard        7.20          2935  $9,183,673.00
# 2                  Bridgetta Clark        7.20          2935  $9,183,673.00
# 3                Rudolph Valentino        7.20          2935  $9,183,673.00
# 4                 Virginia Warwick        7.20          2935  $9,183,673.00
# ...                            ...         ...           ...            ...
# 277451                   Dawn Ford        5.40           227  $1,875,283.00
# 277452              Angela Galuppo        5.40           227  $1,875,283.00
# 277453      Holly Gauthier-Frankel        5.40           227  $1,875,283.00
# 277454   Éloïsa Laflamme-Cervantes        5.40           227  $1,875,283.00
# 277455             Gabriel Lessard        5.40           227  $1,875,283.00
#
#        Lifetime Gross - Adjusted ($)
# 0                    $131,165,937.89
# 1                    $131,165,937.89
# 2                    $131,165,937.89
# 3                    $131,165,937.89
# 4                    $131,165,937.89
# ...                              ...
# 277451                 $1,909,262.69
# 277452                 $1,909,262.69
# 277453                 $1,909,262.69
# 277454                 $1,909,262.69
# 277455                 $1,909,262.69
#
# [277456 rows x 16 columns]

# %%
# Pushing the cleaned DF to a CSV file
stacked_movie_data_actors.to_csv("Data/data_cleaning_stacked_actors.csv")
