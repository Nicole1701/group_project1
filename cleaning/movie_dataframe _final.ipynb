# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import linregress

# %%
# CSV Path
imdb_movies_csv = "Data/imdb_movies.csv"
box_office_csv = "Data/boxoffice.csv"

# %%
# Variables for the seperate data frames 
imdb_df = pd.read_csv(imdb_movies_csv)
box_office_df = pd.read_csv(box_office_csv)

# %%
# Removing columns I do not need
col_imdb_df = imdb_df[['imdb_title_id', 'original_title', 'year', 'date_published', 'genre', 'duration', 'country', 
                         'language', 'director', 'writer', 'production_company', 'actors', 'avg_vote', 'votes']]

col_box_office_df = box_office_df[['title', 'lifetime_gross', 'year']]

# %%
# Renaming columns to be more uniform
col_imdb_df = col_imdb_df.rename(columns={'imdb_title_id': "IMDB ID", 'original_title': 'Title', 'year': 'Year',
                                          'date_published': 'Date Published', 'genre': 'Genre', 'duration': 'Duration',
                                         'country': 'Country', 'language': 'Language', 'director': 'Director', 'writer': 'Writer',
                                         'production_company': 'Production Company', 'actors': 'Actors', 'avg_vote': 'Avg Rating',
                                          'votes': '# of Ratings'})

col_box_office_df = col_box_office_df.rename(columns={'title': 'Title', 'lifetime_gross': 'Lifetime Gross ($)', 'year': 'Year'})

# %%
# Merging data frames
movie_data = pd.merge(col_imdb_df, col_box_office_df, on=['Title', 'Year'], how="inner") 

# Formatting columns
movie_data['Lifetime Gross ($)'] = movie_data['Lifetime Gross ($)'].astype(float).map("${:,.2f}".format)

# %%
# Sort IMDB ID
movie_data.sort_values("IMDB ID", inplace = True)

# %%
# Drop duplicate IMDB ID
movie_data.drop_duplicates(subset ="IMDB ID", keep = False, inplace = True)

# %%
# Pushing the cleaned DF to a CSV file
movie_data.to_csv("Data/movie_data_final_2.csv")

# %%
movie_data.sort_values('Title')
# Out:
#         IMDB ID                 Title  Year Date Published  \
# 5239  tt0790799                 $9.99  2008     2009-09-17
# 960   tt0090557       'Round Midnight  1986     1987-01-09
# 5535  tt1022603  (500) Days of Summer  2009     2009-09-02
# 5673  tt1132193            (Untitled)  2009     2011-06-02
# 246   tt0078721                    10  1979     1980-02-08
# ...         ...                   ...   ...            ...
# 6213  tt1608290           Zoolander 2  2016     2016-02-12
# 4540  tt0383060                  Zoom  2006     2006-10-27
# 488   tt0083365             Zoot Suit  1981     1982-01-01
# 6963  tt2948356              Zootopia  2016     2016-03-18
# 3204  tt0120907              eXistenZ  1999     1999-04-14
#
#                              Genre  Duration             Country  \
# 5239     Animation, Drama, Fantasy        78   Israel, Australia
# 960                   Drama, Music       133         USA, France
# 5535        Comedy, Drama, Romance        95                 USA
# 5673          Comedy, Drama, Music        96                 USA
# 246                Comedy, Romance       122                 USA
# ...                            ...       ...                 ...
# 6213                Action, Comedy       101          USA, Italy
# 4540     Action, Adventure, Comedy        83                 USA
# 488                 Drama, Musical       103                 USA
# 6963  Animation, Adventure, Comedy       108                 USA
# 3204      Horror, Sci-Fi, Thriller        97  UK, France, Canada
#
#                        Language                  Director  \
# 5239                    English           Tatia Rosenthal
# 960             English, French        Bertrand Tavernier
# 5535   English, French, Swedish                 Marc Webb
# 5673                    English           Jonathan Parker
# 246                     English             Blake Edwards
# ...                         ...                       ...
# 6213  English, Italian, Spanish               Ben Stiller
# 4540                    English              Peter Hewitt
# 488                     English               Luis Valdez
# 6963                    English  Byron Howard, Rich Moore
# 3204                    English          David Cronenberg
#
#                                    Writer        Production Company  \
# 5239             Etgar Keret, Etgar Keret                Lama Films
# 960     David Rayfiel, Bertrand Tavernier               Little Bear
# 5535   Scott Neustadter, Michael H. Weber  Fox Searchlight Pictures
# 5673  Catherine DiNapoli, Jonathan Parker       Parker Film Company
# 246                         Blake Edwards      Geoffrey Productions
# ...                                   ...                       ...
# 6213          Justin Theroux, Ben Stiller            Panorama Films
# 4540         Adam Rifkin, David Berenbaum        Revolution Studios
# 488                           Luis Valdez        Universal Pictures
# 6963             Byron Howard, Rich Moore      Walt Disney Pictures
# 3204                     David Cronenberg           Dimension Films
#
#                                                  Actors  Avg Rating  \
# 5239  Geoffrey Rush, Anthony LaPaglia, Samuel Johnso...         6.7
# 960   Dexter Gordon, François Cluzet, Gabrielle Hake...         7.4
# 5535  Joseph Gordon-Levitt, Zooey Deschanel, Geoffre...         7.7
# 5673  Adam Goldberg, Marley Shelton, Eion Bailey, Lu...         6.3
# 246   Dudley Moore, Julie Andrews, Bo Derek, Robert ...         6.1
# ...                                                 ...         ...
# 6213  Justin Bieber, Jon Daly, Penélope Cruz, Ben St...         4.7
# 4540  Tim Allen, Courteney Cox, Chevy Chase, Spencer...         4.3
# 488   Daniel Valdez, Edward James Olmos, Charles Aid...         6.8
# 6963  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...         8.0
# 3204  Jennifer Jason Leigh, Jude Law, Ian Holm, Will...         6.8
#
#       # of Ratings Lifetime Gross ($)
# 5239          3067         $52,384.00
# 960           4351      $3,272,593.00
# 5535        448799     $32,391,374.00
# 5673          2041        $230,600.00
# 246          14286     $74,865,517.00
# ...            ...                ...
# 6213         61163     $28,848,693.00
# 4540         17598     $11,989,328.00
# 488            973      $3,256,082.00
# 6963        396148    $341,268,248.00
# 3204         89035      $2,856,712.00
#
# [7751 rows x 15 columns]
